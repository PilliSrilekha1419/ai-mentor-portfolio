# %% [markdown]
# <a href="https://colab.research.google.com/github/PilliSrilekha1419/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 35.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 88.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 103.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 99.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 83.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 24.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:34:13 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:34:13 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 43830a47-fcf5-4ead-85ac-dd8b7ddca0f0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 00a2ec3a-a5e4-4836-8390-e7d956b4c8cd                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital placement preparation for B.Tech students:                            │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **Online Aptitude Test:** Typically includes sections on quantitative ability, logical reasoning, and      │
# │  verbal ability, acting as the initial screening.                                                               │
# │  *   **Advanced Coding Test:** Candidates who clear the aptitude round proceed to a more challenging coding     │
# │  assessment, often involving 1-2 complex problems.                                                              │
# │  *   **Technical Interview (TR):** Focuses on core computer science concepts, data structures & algorithms,     │
# │  projects, and knowledge of programming languages.                                                              │
# │  *   **Managerial Interview (MR):** Assesses problem-solving approach, teamwork, leadership potential, and      │
# │  sometimes includes scenario-based questions.                                                                   │
# │  *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and general       │
# │  suitability for the company.                                                                                   │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C#  │
# │  is essential, along with OOPs concepts.                                                                        │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental knowledge and application of various DSAs are          │
# │  critical for coding rounds and technical interviews.                                                           │
# │  *   **Databases:** Understanding of SQL queries, relational database concepts (RDBMS), and sometimes basic     │
# │  awareness of NoSQL databases.                                                                                  │
# │  *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript) and back-end frameworks (e.g.,    │
# │  Spring Boot, Node.js, Django) is a plus.                                                                       │
# │  *   **Cloud & Emerging Technologies:** Basic understanding of cloud platforms (AWS, Azure, GCP), AI/ML         │
# │  concepts, IoT, or Data Science is increasingly valued for Digital roles.                                       │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Academic Criteria:** A consistent academic record with typically a minimum of 60% or 6.0 CGPA            │
# │  throughout 10th, 12th, and B.Tech/BE.                                                                          │
# │  *   **Degree:** B.Tech/BE in Computer Science Engineering (CSE), Information Technology (IT), Electronics and  │
# │  Communication Engineering (ECE), Electrical and Electronics Engineering (EEE), or related disciplines.         │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or offer acceptance.                   │
# │  *   **Education Gap:** Generally, a maximum of 1-2 years of gap in academic career might be permissible,       │
# │  depending on the specific year's policy.                                                                       │
# │  *   **Age Limit:** Candidates typically need to be within the age range of 18-28 years as per TCS guidelines.  │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Emphasis on Advanced Coding:** Increased focus on problem-solving skills demonstrated through            │
# │  competitive programming and advanced DSA knowledge.                                                            │
# │  *   **Emerging Tech Readiness:** Higher preference for candidates who have foundational knowledge or projects  │
# │  in AI/ML, Cloud Computing, Blockchain, or Data Analytics.                                                      │
# │  *   **Project-Based Learning:** Candidates with strong, well-explained personal projects and internships       │
# │  showcasing practical application of skills are highly sought after.                                            │
# │  *   **Strong Communication & Aptitude:** Apart from technical prowess, excellent communication skills and      │
# │  robust aptitude scores remain crucial for Digital selection.                                                   │
# │  *   **Domain Specificity:** Some Digital roles now look for candidates with an inclination towards specific    │
# │  industry domains (e.g., Banking, Healthcare, Retail).                                                          │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on         │
# │  platforms like LeetCode, HackerRank, focusing on medium to hard problems.                                      │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, Computer Networks, and     │
# │  Object-Oriented Programming (OOPs) concepts.                                                                   │
# │  *   **Build Relevant Projects:** Develop 2-3 significant projects using modern technologies; be prepared to    │
# │  articulate your role, challenges faced, and architectural choices.                                             │
# │  *   **Practice Aptitude Regularly:** Solve previous year's aptitude questions for TCS or similar companies to  │
# │  improve speed and accuracy in quantitative, logical, and verbal reasoning.                                     │
# │  *   **Refine Communication & Interview Skills:** Practice mock interviews, work on clearly explaining          │
# │  technical concepts, and prepare for behavioral and situational questions often asked in HR/MR rounds.          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 45ff450d-8a15-48ad-8d24-eb13c9f6bc6e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Ready to embark on a transformative career journey with a global leader in digital innovation?                 │
# │  TCS Digital offers B.Tech students a gateway to cutting-edge technologies and impactful projects.              │
# │  This brief is your essential guide to navigating the TCS Digital hiring process successfully.                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## The Road to TCS Digital: Hiring Process                                                                     │
# │                                                                                                                 │
# │  The selection journey for TCS Digital is rigorous, designed to identify top talent across multiple             │
# │  dimensions.                                                                                                    │
# │  *   **Online Aptitude Test:** Initial screening covering quantitative ability, logical reasoning, and verbal   │
# │  ability. Focus on speed and accuracy.                                                                          │
# │  *   **Advanced Coding Test:** For those who clear aptitude, this round involves 1-2 complex coding problems,   │
# │  testing problem-solving and implementation skills.                                                             │
# │  *   **Technical Interview (TR):** Deep dive into core CS concepts, Data Structures & Algorithms, project       │
# │  discussions, and programming language proficiency.                                                             │
# │  *   **Managerial Interview (MR):** Assesses your problem-solving approach, teamwork capabilities, leadership   │
# │  potential, and sometimes includes scenario-based questions.                                                    │
# │  *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and overall       │
# │  suitability for a dynamic work environment.                                                                    │
# │                                                                                                                 │
# │  ## Your Digital Toolkit: Technical Stack                                                                       │
# │                                                                                                                 │
# │  A strong foundation in these technical areas will be crucial for success in the coding rounds and interviews.  │
# │  *   **Core Programming Languages:** Master at least one (Java, Python, C++, C#) with strong Object-Oriented    │
# │  Programming (OOPs) concepts.                                                                                   │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental knowledge and practical application of various DSAs    │
# │  are paramount.                                                                                                 │
# │  *   **Databases:** Understand SQL queries, Relational Database Management Systems (RDBMS) concepts, and basic  │
# │  awareness of NoSQL databases.                                                                                  │
# │  *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript) and back-end frameworks (e.g.,    │
# │  Spring Boot, Node.js, Django) is a significant advantage.                                                      │
# │  *   **Cloud & Emerging Technologies:** Basic understanding of cloud platforms (AWS, Azure, GCP), AI/ML         │
# │  concepts, IoT, or Data Science is increasingly valued for Digital roles.                                       │
# │                                                                                                                 │
# │  ## Are You Eligible? Key Criteria                                                                              │
# │                                                                                                                 │
# │  Meeting these foundational requirements is the first step towards your TCS Digital opportunity.                │
# │  *   **Academic Criteria:** Consistent academic record with typically a minimum of 60% or 6.0 CGPA throughout   │
# │  10th, 12th, and B.Tech/BE.                                                                                     │
# │  *   **Degree:** B.Tech/BE in Computer Science Engineering (CSE), Information Technology (IT), Electronics and  │
# │  Communication Engineering (ECE), Electrical and Electronics Engineering (EEE), or related disciplines.         │
# │  *   **Backlogs:** No active backlogs allowed at the time of application or offer acceptance.                   │
# │  *   **Education Gap:** Generally, a maximum of 1-2 years of gap in academic career might be permissible,       │
# │  depending on the specific year's policy.                                                                       │
# │  *   **Age Limit:** Candidates typically need to be within the age range of 18-28 years as per TCS guidelines.  │
# │                                                                                                                 │
# │  ## What's Hot: Recent Hiring Trends                                                                            │
# │                                                                                                                 │
# │  TCS Digital is evolving, and so are its expectations from prospective candidates.                              │
# │  *   **Emphasis on Advanced Coding:** Increased focus on problem-solving skills demonstrated through            │
# │  competitive programming and advanced DSA knowledge.                                                            │
# │  *   **Emerging Tech Readiness:** Higher preference for candidates with foundational knowledge or projects in   │
# │  AI/ML, Cloud Computing, Blockchain, or Data Analytics.                                                         │
# │  *   **Project-Based Learning:** Candidates with strong, well-explained personal projects and internships       │
# │  showcasing practical application of skills are highly sought after.                                            │
# │  *   **Strong Communication & Aptitude:** Apart from technical prowess, excellent communication skills and      │
# │  robust aptitude scores remain crucial for Digital selection.                                                   │
# │  *   **Domain Specificity:** Some Digital roles now look for candidates with an inclination towards specific    │
# │  industry domains (e.g., Banking, Healthcare, Retail).                                                          │
# │                                                                                                                 │
# │  ## Your Game Plan: Preparation Tips                                                                            │
# │                                                                                                                 │
# │  Strategize your preparation to maximize your chances of securing a coveted TCS Digital role.                   │
# │  *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on         │
# │  platforms like LeetCode, HackerRank, focusing on medium to hard problems.                                      │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, Computer Networks, and     │
# │  Object-Oriented Programming (OOPs) concepts.                                                                   │
# │  *   **Build Relevant Projects:** Develop 2-3 significant projects using modern technologies; be prepared to    │
# │  articulate your role, challenges faced, and architectural choices.                                             │
# │  *   **Practice Aptitude Regularly:** Solve previous year's aptitude questions for TCS or similar companies to  │
# │  improve speed and accuracy in quantitative, logical, and verbal reasoning.                                     │
# │  *   **Refine Communication & Interview Skills:** Practice mock interviews, work on clearly explaining          │
# │  technical concepts, and prepare for behavioral and situational questions often asked in HR/MR rounds.          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Success at TCS Digital demands focused preparation and a proactive approach.                                   │
# │  Start early, practice diligently, and showcase your passion for technology.                                    │
# │  Your digital future awaits – seize the opportunity!                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Ready to embark on a transformative career journey with a global leader in digital innovation?
# TCS Digital offers B.Tech students a gateway to cutting-edge technologies and impactful projects.
# This brief is your essential guide to navigating the TCS Digital hiring process successfully.
#
# ---
#
# ## The Road to TCS Digital: Hiring Process
#
# The selection journey for TCS Digital is rigorous, designed to identify top talent across multiple dimensions.
# *   **Online Aptitude Test:** Initial screening covering quantitative ability, logical reasoning, and verbal ability. Focus on speed and accuracy.
# *   **Advanced Coding Test:** For those who clear aptitude, this round involves 1-2 complex coding problems, testing problem-solving and implementation skills.
# *   **Technical Interview (TR):** Deep dive into core CS concepts, Data Structures & Algorithms, project discussions, and programming language proficiency.
# *   **Managerial Interview (MR):** Assesses your problem-solving approach, teamwork capabilities, leadership potential, and sometimes includes scenario-based questions.
# *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and overall suitability for a dynamic work environment.
#
# ## Your Digital Toolkit: Technical Stack
#
# A strong foundation in these technical areas will be crucial for success in the coding rounds and interviews.
# *   **Core Programming Languages:** Master at least one (Java, Python, C++, C#) with strong Object-Oriented Programming (OOPs) concepts.
# *   **Data Structures & Algorithms (DSA):** Fundamental knowledge and practical application of various DSAs are paramount.
# *   **Databases:** Understand SQL queries, Relational Database Management Systems (RDBMS) concepts, and basic awareness of NoSQL databases.
# *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript) and back-end frameworks (e.g., Spring Boot, Node.js, Django) is a significant advantage.
# *   **Cloud & Emerging Technologies:** Basic understanding of cloud platforms (AWS, Azure, GCP), AI/ML concepts, IoT, or Data Science is increasingly valued for Digital roles.
#
# ## Are You Eligible? Key Criteria
#
# Meeting these foundational requirements is the first step towards your TCS Digital opportunity.
# *   **Academic Criteria:** Consistent academic record with typically a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech/BE.
# *   **Degree:** B.Tech/BE in Computer Science Engineering (CSE), Information Technology (IT), Electronics and Communication Engineering (ECE), Electrical and Electronics Engineering (EEE), or related disciplines.
# *   **Backlogs:** No active backlogs allowed at the time of application or offer acceptance.
# *   **Education Gap:** Generally, a maximum of 1-2 years of gap in academic career might be permissible, depending on the specific year's policy.
# *   **Age Limit:** Candidates typically need to be within the age range of 18-28 years as per TCS guidelines.
#
# ## What's Hot: Recent Hiring Trends
#
# TCS Digital is evolving, and so are its expectations from prospective candidates.
# *   **Emphasis on Advanced Coding:** Increased focus on problem-solving skills demonstrated through competitive programming and advanced DSA knowledge.
# *   **Emerging Tech Readiness:** Higher preference for candidates with foundational knowledge or projects in AI/ML, Cloud Computing, Blockchain, or Data Analytics.
# *   **Project-Based Learning:** Candidates with strong, well-explained personal projects and internships showcasing practical application of skills are highly sought after.
# *   **Strong Communication & Aptitude:** Apart from technical prowess, excellent communication skills and robust aptitude scores remain crucial for Digital selection.
# *   **Domain Specificity:** Some Digital roles now look for candidates with an inclination towards specific industry domains (e.g., Banking, Healthcare, Retail).
#
# ## Your Game Plan: Preparation Tips
#
# Strategize your preparation to maximize your chances of securing a coveted TCS Digital role.
# *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on platforms like LeetCode, HackerRank, focusing on medium to hard problems.
# *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, Computer Networks, and Object-Oriented Programming (OOPs) concepts.
# *   **Build Relevant Projects:** Develop 2-3 significant projects using modern technologies; be prepared to articulate your role, challenges faced, and architectural choices.
# *   **Practice Aptitude Regularly:** Solve previous year's aptitude questions for TCS or similar companies to improve speed and accuracy in quantitative, logical, and verbal reasoning.
# *   **Refine Communication & Interview Skills:** Practice mock interviews, work on clearly explaining technical concepts, and prepare for behavioral and situational questions often asked in HR/MR rounds.
#
# ---
#
# Success at TCS Digital demands focused preparation and a proactive approach.
# Start early, practice diligently, and showcase your passion for technology.
# Your digital future awaits – seize the opportunity!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 5164

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital placement preparation for B.Tech students:
#
# ### Hiring Process
#
# *   **Online Aptitude Test:** Typically includes sections on quantitative ability, logical reasoning, and verbal ability, acting as the initial screening.
# *   **Advanced Coding Test:** Candidates who clear the aptitude round proceed to a more challenging coding assessment, often involving 1-2 complex problems.
# *   **Technical Interview (TR):** Focuses on core computer science concepts, data structures & algorithms, projects, and knowledge of programming languages.
# *   **Managerial Interview (MR):** Assesses problem-solving approach, teamwork, leadership potential, and sometimes includes scenario-based questions.
# *   **HR Interview (HR):** Evaluates communication skills, cultural fit, ca
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Ready to embark on a transformative career journey with a global leader in digital innovation?
# TCS Digital offers B.Tech students a gateway to cutting-edge technologies and impactful projects.
# This brief is your essential guide to navigating the TCS Digital hiring process successfully.
#
# ---
#
# ## The Road to TCS Digital: Hiring Process
#
# The selection journey for TCS Digital is rigorous, designed to identify top talent across multiple dimensions.
# *   **Online Aptitude Test:** Initial screening covering quantitative ability, logical reasoning, and verbal ability. Focus on speed and accuracy.
# *   **Advanced Coding Test:** For those who clear aptitude, this round involves 1-2 complex coding problems, testing problem-solving and implementation skills.
# *   **T

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Ready to embark on a transformative career journey with a global leader in digital innovation?
# TCS Digital offers B.Tech students a gateway to cutting-edge technologies and impactful projects.
# This brief is your essential guide to navigating the TCS Digital hiring process successfully.
#
# ---
#
# ## The Road to TCS Digital: Hiring Process
#
# The selection journey for TCS Digital is rigorous, designed to identify top talent across multiple dimensions.
# *   **Online Aptitude Test:** Initial screening covering quantitative ability, logical reasoning, and verbal ability. Focus on speed and accuracy.
# *   **Advanced Coding Test:** For those who clear aptitude, this round involves 1-2 complex coding problems, testing problem-solving and implementation skills.
# *   **Technical Interview (TR):** Deep dive into core CS concepts, Data Structures & Algorithms, project discussions, and programming language proficiency.
# *   **Managerial Interview (MR):** Assesses your problem-solving approach, teamwork capabilities, leadership potential, and sometimes includes scenario-based questions.
# *   **HR Interview (HR):** Evaluates communication skills, cultural fit, career aspirations, and overall suitability for a dynamic work environment.
#
# ## Your Digital Toolkit: Technical Stack
#
# A strong foundation in these technical areas will be crucial for success in the coding rounds and interviews.
# *   **Core Programming Languages:** Master at least one (Java, Python, C++, C#) with strong Object-Oriented Programming (OOPs) concepts.
# *   **Data Structures & Algorithms (DSA):** Fundamental knowledge and practical application of various DSAs are paramount.
# *   **Databases:** Understand SQL queries, Relational Database Management Systems (RDBMS) concepts, and basic awareness of NoSQL databases.
# *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript) and back-end frameworks (e.g., Spring Boot, Node.js, Django) is a significant advantage.
# *   **Cloud &
